# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.stats import pearsonr, spearmanr

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Core settings
metrics = ["bleu", "meteor", "comet_ref", "comet_wmt22"]
metric_labels = ["BLEU", "METEOR", "COMET-REF", "COMET-WMT22"]
systems = ["Original", "Bottom-1", "Average", "Top-1"]
colors = {
    "Top-1": "#ff7f0e",
    "Average": "#d62728",
    "Bottom-1": "#2ca02c",
    "Original": "#1f77b4"
}
width = 0.18
x = np.arange(len(metrics))  # One x per metric

# File paths, insert your own paths here
langpair = "eng-fra"
original_path = r"C:\Users\gerri\Documents\jaar3\thesis\exp1\csv_results_560\eng-fra_bloomz-560_flores200_results.csv"
distilled_path = r"C:\Users\gerri\Documents\jaar3\thesis\\exp2\translations\csv_results\high_dist_eng-fra_bloomz-560_flores200_results.csv"
average_path = r"C:\Users\gerri\Documents\jaar3\thesis\exp2\translations\csv_results\avg_dist_eng-fra_bloomz-560_flores200_results.csv"
bad_path = r"C:\Users\gerri\Documents\jaar3\thesis\exp2\translations\csv_results\bad_dist_eng-fra_bloomz-560_flores200_results.csv"

# Data
try:
    df_orig = pd.read_csv(original_path)
    df_dist = pd.read_csv(distilled_path)
    df_avg = pd.read_csv(average_path)
    df_bad = pd.read_csv(bad_path)
except Exception as e:
    print(f"Error loading data for {langpair}: {e}")
    raise

# Collect scores
scores_orig, scores_dist, scores_avg, scores_bad = [], [], [], []

for metric in metrics:
    orig_score = df_orig[df_orig["strategy"] == "greedy"][metric].mean()
    dist_score = df_dist[df_dist["strategy"] == "greedy"][metric].mean()
    avg_score = df_avg[df_avg["strategy"] == "greedy"][metric].mean()
    bad_score = df_bad[df_bad["strategy"] == "greedy"][metric].mean()

    if metric == "bleu":
        orig_score /= 100
        dist_score /= 100
        avg_score /= 100
        bad_score /= 100

    scores_orig.append(orig_score)
    scores_dist.append(dist_score)
    scores_avg.append(avg_score)
    scores_bad.append(bad_score)

# Plot
fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(x - 1.5 * width, scores_orig, width, label="Original", color=colors["Original"])
ax.bar(x - 0.5 * width, scores_bad, width, label="Bottom-1", color=colors["Bottom-1"])
ax.bar(x + 0.5 * width, scores_avg, width, label="Average", color=colors["Average"])
ax.bar(x + 1.5 * width, scores_dist, width, label="Top-1", color=colors["Top-1"])

ax.set_title(f"{langpair.upper()} (Greedy)", fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(metric_labels, rotation=15)
ax.set_ylabel("Score")
ax.set_ylim(0, max(scores_orig + scores_dist + scores_avg + scores_bad) * 1.2)
ax.grid(axis="y", linestyle="--", alpha=0.5)

# Legend
ax.legend(title="System", loc="upper left", bbox_to_anchor=(1.02, 1.0))

fig.suptitle("Translation quality across finetuning", fontsize=16)
plt.tight_layout(rect=[0, 0, 0.95, 0.95])
plt.show()

# %%
metric = "perplexity" 
# Define core settings
metrics = ["bleu", "meteor", "comet_ref", "comet_wmt22-cometkiwi-da", "perplexity"]
metric_labels = ["BLEU", "METEOR", "COMET-REF", "COMET-WMT22"]
systems = ["Original", "Top-1", "Average", "Bottom-1"]
lang_dirs = ["eng-fra"]
colors = {
    "Top-1": "#ff7f0e",
    "Average": "#d62728",
    "Bottom-1": "#2ca02c",
    "Original": "#1f77b4"
}
width = 0.18
x = np.arange(len(systems))

# File paths, insert your own paths here
original_paths = {
    "eng-fra": r"C:\Users\gerri\Documents\jaar3\thesis\exp1\csv_results_560\eng-fra_bloomz-560_flores200_results.csv"
}
distilled_paths = {
    "eng-fra": r"C:\Users\gerri\Documents\jaar3\thesis\exp2\translations\csv_results\high_dist_eng-fra_bloomz-560_flores200_results.csv"
}
average_paths = {
    "eng-fra": r"C:\Users\gerri\Documents\jaar3\thesis\exp2\translations\csv_results\avg_dist_eng-fra_bloomz-560_flores200_results.csv"
}
bad_paths = {
    "eng-fra": r"C:\Users\gerri\Documents\jaar3\thesis\exp2\translations\csv_results\bad_dist_eng-fra_bloomz-560_flores200_results.csv"
}

# Plotting
fig, ax = plt.subplots(figsize=(8, 6))

for langpair in lang_dirs:
    try:
        df_orig = pd.read_csv(original_paths[langpair])
        df_dist = pd.read_csv(distilled_paths[langpair])
        df_avg = pd.read_csv(average_paths[langpair])
        df_bad = pd.read_csv(bad_paths[langpair])
    except Exception as e:
        print(f"Error reading files for {langpair}: {e}")
        continue

    # Extract scores
    def get_score(df):
        val = df[df["strategy"] == "greedy"][metric].mean()
        return -val if metric == "perplexity" else val

    orig_score = get_score(df_orig)
    dist_score = get_score(df_dist)
    avg_score = get_score(df_avg)
    bad_score = get_score(df_bad)

    scores = [orig_score, dist_score, avg_score, bad_score]

    # Plot
    ax.bar(x, scores, width=0.45, color=[colors[s] for s in systems])
    title_metric = "Confidence (−Perplexity)" if metric == "perplexity" else metric.upper()
    ax.set_title(f"{langpair.upper()} - {title_metric}", fontsize=14)
    ax.set_xticks(x)
    ax.set_xticklabels(systems, rotation=15)
    ax.set_ylabel("Score")
    ax.grid(axis='y', linestyle='--', alpha=0.5)

# Legend
handles = [plt.Rectangle((0, 0), 1, 1, color=colors[s]) for s in systems]
ax.legend(handles, systems, title="System", ncol=1, bbox_to_anchor=(1.02, 1.0))
fig.suptitle("Model confidence across finetuning", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Define model variants and file paths, insert your own paths here
model_variants = {
    "Finetuned with top-1": {
        "eng-fra": (r"C:\Users\gerri\Documents\jaar3\thesis\exp2\translations\csv_results", "high_dist_eng-fra_bloomz-560_flores200_results.csv")
    },
    "Finetuned with average": {
        "eng-fra": (r"C:\Users\gerri\Documents\jaar3\thesis\exp2\translations\csv_results", "avg_dist_eng-fra_bloomz-560_flores200_results.csv")
    },
    "Finetuned with bottom-1": {
        "eng-fra": (r"C:\Users\gerri\Documents\jaar3\thesis\exp2\translations\csv_results", "bad_dist_eng-fra_bloomz-560_flores200_results.csv")
    },
    "Standard": {
        "eng-fra": (r"C:\Users\gerri\Documents\jaar3\thesis\exp1\csv_results_560", "eng-fra_bloomz-560_flores200_results.csv")
    }
}

lang_pairs = ["eng-fra"]
quality_metrics = ["bleu", "meteor", "comet_ref", "comet_wmt22"]

# Data
quality_data = []
confidence_data = []

for lp in lang_pairs:
    quality_row = {}
    confidence_row = {}
    src, tgt = lp.split("-")

    for variant, file_map in model_variants.items():
        if lp not in file_map:
            for metric in quality_metrics:
                quality_row[(variant, metric.upper())] = None
            for m in ["Confidence", "Pearson"]:
                confidence_row[(variant, m)] = None
            continue

        folder, filename = file_map[lp]
        file_path = os.path.join(folder, filename)

        if not os.path.exists(file_path):
            for metric in quality_metrics:
                quality_row[(variant, metric.upper())] = None
            for m in ["Confidence", "Pearson"]:
                confidence_row[(variant, m)] = None
            continue

        df = pd.read_csv(file_path)
        sub = df[df["strategy"] == "greedy"]

        if sub.empty:
            for metric in quality_metrics:
                quality_row[(variant, metric.upper())] = None
            for m in ["Confidence", "Pearson"]:
                confidence_row[(variant, m)] = None
            continue

        for metric in quality_metrics:
            quality_row[(variant, metric.upper())] = sub[metric].mean()

        # Confidence and correlation
        x = -sub["perplexity"]
        y = sub["comet_ref"]
        confidence_row[(variant, "Confidence")] = x.mean()

        # Clean NaNs/Infs
        xy = pd.DataFrame({"x": x, "y": y}).dropna()
        xy = xy[np.isfinite(xy["x"]) & np.isfinite(xy["y"])]
        x_clean, y_clean = xy["x"], xy["y"]

        if len(x_clean) >= 2 and x_clean.std() > 0 and y_clean.std() > 0:
            confidence_row[(variant, "Pearson")], _ = pearsonr(x_clean, y_clean)
        else:
            confidence_row[(variant, "Pearson")] = None

        if len(x_clean) >= 2 and x_clean.nunique() > 1 and y_clean.nunique() > 1:
            confidence_row[(variant, "Spearman")], _ = spearmanr(x_clean, y_clean)
        else:
            confidence_row[(variant, "Spearman")] = None

    quality_row[("Language Pair", "")] = lp
    confidence_row[("Language Pair", "")] = lp
    quality_data.append(quality_row)
    confidence_data.append(confidence_row)

# Tables
df_quality = pd.DataFrame(quality_data).set_index(("Language Pair", ""))
df_confidence = pd.DataFrame(confidence_data).set_index(("Language Pair", ""))

df_quality.columns = pd.MultiIndex.from_tuples(df_quality.columns)
df_confidence.columns = pd.MultiIndex.from_tuples(df_confidence.columns)

df_quality.loc["Average"] = df_quality.mean(numeric_only=True)
df_confidence.loc["Average"] = df_confidence.mean(numeric_only=True)

def style_table(df):
    return df.style.set_properties(**{
        'background-color': 'white',
        'color': 'black',
        'border-color': 'black'
    })

display(style_table(df_quality))
display(style_table(df_confidence))
# Out:
# <style type="text/css">
# #T_b2274_row0_col0, #T_b2274_row0_col1, #T_b2274_row0_col2, #T_b2274_row0_col3, #T_b2274_row0_col4, #T_b2274_row0_col5, #T_b2274_row0_col6, #T_b2274_row0_col7, #T_b2274_row0_col8, #T_b2274_row0_col9, #T_b2274_row0_col10, #T_b2274_row0_col11, #T_b2274_row0_col12, #T_b2274_row0_col13, #T_b2274_row0_col14, #T_b2274_row0_col15, #T_b2274_row1_col0, #T_b2274_row1_col1, #T_b2274_row1_col2, #T_b2274_row1_col3, #T_b2274_row1_col4, #T_b2274_row1_col5, #T_b2274_row1_col6, #T_b2274_row1_col7, #T_b2274_row1_col8, #T_b2274_row1_col9, #T_b2274_row1_col10, #T_b2274_row1_col11, #T_b2274_row1_col12, #T_b2274_row1_col13, #T_b2274_row1_col14, #T_b2274_row1_col15 {
#   background-color: white;
#   color: black;
#   border-color: black;
# }
# </style>
# <table id="T_b2274">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2274_level0_col0" class="col_heading level0 col0" colspan="4">Finetuned with top-1</th>
#       <th id="T_b2274_level0_col4" class="col_heading level0 col4" colspan="4">Finetuned with average</th>
#       <th id="T_b2274_level0_col8" class="col_heading level0 col8" colspan="4">Finetuned with bottom-1</th>
#       <th id="T_b2274_level0_col12" class="col_heading level0 col12" colspan="4">Standard</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_b2274_level1_col0" class="col_heading level1 col0" >BLEU</th>
#       <th id="T_b2274_level1_col1" class="col_heading level1 col1" >METEOR</th>
#       <th id="T_b2274_level1_col2" class="col_heading level1 col2" >COMET_REF</th>
#       <th id="T_b2274_level1_col3" class="col_heading level1 col3" >COMET_WMT22</th>
#       <th id="T_b2274_level1_col4" class="col_heading level1 col4" >BLEU</th>
#       <th id="T_b2274_level1_col5" class="col_heading level1 col5" >METEOR</th>
#       <th id="T_b2274_level1_col6" class="col_heading level1 col6" >COMET_REF</th>
#       <th id="T_b2274_level1_col7" class="col_heading level1 col7" >COMET_WMT22</th>
#       <th id="T_b2274_level1_col8" class="col_heading level1 col8" >BLEU</th>
#       <th id="T_b2274_level1_col9" class="col_heading level1 col9" >METEOR</th>
#       <th id="T_b2274_level1_col10" class="col_heading level1 col10" >COMET_REF</th>
#       <th id="T_b2274_level1_col11" class="col_heading level1 col11" >COMET_WMT22</th>
#       <th id="T_b2274_level1_col12" class="col_heading level1 col12" >BLEU</th>
#       <th id="T_b2274_level1_col13" class="col_heading level1 col13" >METEOR</th>
#       <th id="T_b2274_level1_col14" class="col_heading level1 col14" >COMET_REF</th>
#       <th id="T_b2274_level1_col15" class="col_heading level1 col15" >COMET_WMT22</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >('Language Pair', '')</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2274_level0_row0" class="row_heading level0 row0" >eng-fra</th>
#       <td id="T_b2274_row0_col0" class="data row0 col0" >37.837757</td>
#       <td id="T_b2274_row0_col1" class="data row0 col1" >0.625298</td>
#       <td id="T_b2274_row0_col2" class="data row0 col2" >0.834069</td>
#       <td id="T_b2274_row0_col3" class="data row0 col3" >0.819840</td>
#       <td id="T_b2274_row0_col4" class="data row0 col4" >37.409890</td>
#       <td id="T_b2274_row0_col5" class="data row0 col5" >0.618044</td>
#       <td id="T_b2274_row0_col6" class="data row0 col6" >0.827411</td>
#       <td id="T_b2274_row0_col7" class="data row0 col7" >0.812858</td>
#       <td id="T_b2274_row0_col8" class="data row0 col8" >37.459716</td>
#       <td id="T_b2274_row0_col9" class="data row0 col9" >0.624883</td>
#       <td id="T_b2274_row0_col10" class="data row0 col10" >0.834362</td>
#       <td id="T_b2274_row0_col11" class="data row0 col11" >0.818729</td>
#       <td id="T_b2274_row0_col12" class="data row0 col12" >34.720720</td>
#       <td id="T_b2274_row0_col13" class="data row0 col13" >0.594777</td>
#       <td id="T_b2274_row0_col14" class="data row0 col14" >0.819891</td>
#       <td id="T_b2274_row0_col15" class="data row0 col15" >0.804279</td>
#     </tr>
#     <tr>
#       <th id="T_b2274_level0_row1" class="row_heading level0 row1" >Average</th>
#       <td id="T_b2274_row1_col0" class="data row1 col0" >37.837757</td>
#       <td id="T_b2274_row1_col1" class="data row1 col1" >0.625298</td>
#       <td id="T_b2274_row1_col2" class="data row1 col2" >0.834069</td>
#       <td id="T_b2274_row1_col3" class="data row1 col3" >0.819840</td>
#       <td id="T_b2274_row1_col4" class="data row1 col4" >37.409890</td>
#       <td id="T_b2274_row1_col5" class="data row1 col5" >0.618044</td>
#       <td id="T_b2274_row1_col6" class="data row1 col6" >0.827411</td>
#       <td id="T_b2274_row1_col7" class="data row1 col7" >0.812858</td>
#       <td id="T_b2274_row1_col8" class="data row1 col8" >37.459716</td>
#       <td id="T_b2274_row1_col9" class="data row1 col9" >0.624883</td>
#       <td id="T_b2274_row1_col10" class="data row1 col10" >0.834362</td>
#       <td id="T_b2274_row1_col11" class="data row1 col11" >0.818729</td>
#       <td id="T_b2274_row1_col12" class="data row1 col12" >34.720720</td>
#       <td id="T_b2274_row1_col13" class="data row1 col13" >0.594777</td>
#       <td id="T_b2274_row1_col14" class="data row1 col14" >0.819891</td>
#       <td id="T_b2274_row1_col15" class="data row1 col15" >0.804279</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_894af_row0_col0, #T_894af_row0_col1, #T_894af_row0_col2, #T_894af_row0_col3, #T_894af_row0_col4, #T_894af_row0_col5, #T_894af_row0_col6, #T_894af_row0_col7, #T_894af_row0_col8, #T_894af_row0_col9, #T_894af_row0_col10, #T_894af_row0_col11, #T_894af_row1_col0, #T_894af_row1_col1, #T_894af_row1_col2, #T_894af_row1_col3, #T_894af_row1_col4, #T_894af_row1_col5, #T_894af_row1_col6, #T_894af_row1_col7, #T_894af_row1_col8, #T_894af_row1_col9, #T_894af_row1_col10, #T_894af_row1_col11 {
#   background-color: white;
#   color: black;
#   border-color: black;
# }
# </style>
# <table id="T_894af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_894af_level0_col0" class="col_heading level0 col0" colspan="3">Finetuned with top-1</th>
#       <th id="T_894af_level0_col3" class="col_heading level0 col3" colspan="3">Finetuned with average</th>
#       <th id="T_894af_level0_col6" class="col_heading level0 col6" colspan="3">Finetuned with bottom-1</th>
#       <th id="T_894af_level0_col9" class="col_heading level0 col9" colspan="3">Standard</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_894af_level1_col0" class="col_heading level1 col0" >Confidence</th>
#       <th id="T_894af_level1_col1" class="col_heading level1 col1" >Pearson</th>
#       <th id="T_894af_level1_col2" class="col_heading level1 col2" >Spearman</th>
#       <th id="T_894af_level1_col3" class="col_heading level1 col3" >Confidence</th>
#       <th id="T_894af_level1_col4" class="col_heading level1 col4" >Pearson</th>
#       <th id="T_894af_level1_col5" class="col_heading level1 col5" >Spearman</th>
#       <th id="T_894af_level1_col6" class="col_heading level1 col6" >Confidence</th>
#       <th id="T_894af_level1_col7" class="col_heading level1 col7" >Pearson</th>
#       <th id="T_894af_level1_col8" class="col_heading level1 col8" >Spearman</th>
#       <th id="T_894af_level1_col9" class="col_heading level1 col9" >Confidence</th>
#       <th id="T_894af_level1_col10" class="col_heading level1 col10" >Pearson</th>
#       <th id="T_894af_level1_col11" class="col_heading level1 col11" >Spearman</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >('Language Pair', '')</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_894af_level0_row0" class="row_heading level0 row0" >eng-fra</th>
#       <td id="T_894af_row0_col0" class="data row0 col0" >-1.408366</td>
#       <td id="T_894af_row0_col1" class="data row0 col1" >0.701408</td>
#       <td id="T_894af_row0_col2" class="data row0 col2" >0.737664</td>
#       <td id="T_894af_row0_col3" class="data row0 col3" >-1.417957</td>
#       <td id="T_894af_row0_col4" class="data row0 col4" >0.586671</td>
#       <td id="T_894af_row0_col5" class="data row0 col5" >0.701361</td>
#       <td id="T_894af_row0_col6" class="data row0 col6" >-1.397848</td>
#       <td id="T_894af_row0_col7" class="data row0 col7" >0.704755</td>
#       <td id="T_894af_row0_col8" class="data row0 col8" >0.745897</td>
#       <td id="T_894af_row0_col9" class="data row0 col9" >-1.601564</td>
#       <td id="T_894af_row0_col10" class="data row0 col10" >0.582637</td>
#       <td id="T_894af_row0_col11" class="data row0 col11" >0.638000</td>
#     </tr>
#     <tr>
#       <th id="T_894af_level0_row1" class="row_heading level0 row1" >Average</th>
#       <td id="T_894af_row1_col0" class="data row1 col0" >-1.408366</td>
#       <td id="T_894af_row1_col1" class="data row1 col1" >0.701408</td>
#       <td id="T_894af_row1_col2" class="data row1 col2" >0.737664</td>
#       <td id="T_894af_row1_col3" class="data row1 col3" >-1.417957</td>
#       <td id="T_894af_row1_col4" class="data row1 col4" >0.586671</td>
#       <td id="T_894af_row1_col5" class="data row1 col5" >0.701361</td>
#       <td id="T_894af_row1_col6" class="data row1 col6" >-1.397848</td>
#       <td id="T_894af_row1_col7" class="data row1 col7" >0.704755</td>
#       <td id="T_894af_row1_col8" class="data row1 col8" >0.745897</td>
#       <td id="T_894af_row1_col9" class="data row1 col9" >-1.601564</td>
#       <td id="T_894af_row1_col10" class="data row1 col10" >0.582637</td>
#       <td id="T_894af_row1_col11" class="data row1 col11" >0.638000</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt

variants_order = [
    "Finetuned with top-1",
    "Finetuned with average",
    "Finetuned with bottom-1"
]

# Extract Pearson and Spearman scores from df_confidence
pearson_scores_a = [df_confidence.loc["eng-fra"][(variant, "Pearson")] for variant in variants_order]
spearman_scores_a = [df_confidence.loc["eng-fra"][(variant, "Spearman")] for variant in variants_order]
pearson_standard_a = df_confidence.loc["eng-fra"][("Standard", "Pearson")]
spearman_standard_a = df_confidence.loc["eng-fra"][("Standard", "Spearman")]

# X-axis labels
labels = ["bottom-1", "average", "top-1"]
x = range(len(labels))

# Plot
plt.figure(figsize=(8, 5))
plt.plot(x, pearson_scores_a, marker="o", linestyle="-", label="Pearson correlation (eng-fra)")
plt.plot(x, spearman_scores_a, marker="o", linestyle="-", label="Spearman correlation (eng-fra)")

plt.axhline(y=pearson_standard_a, color="blue", linestyle="--", linewidth=1, label="Pearson eng-fra (Standard)")
plt.axhline(y=spearman_standard_a, color="green", linestyle="--", linewidth=1, label="Spearman eng-fra (Standard)")

plt.xticks(x, labels, rotation=15)
plt.ylabel("Correlation (-Perplexity vs COMET-Ref)")
plt.xlabel("Finetuning Quality (Comet-Ref)")
plt.title("Correlation (Confidence and Quality) vs Finetuning Quality")
plt.grid(True, linestyle="--", alpha=0.6)
plt.ylim(0.5, 1.0)
plt.tight_layout()
plt.legend()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2, frameon=True)
plt.show()

# %%
# Export to LaTeX file
with open("french_app_quality_metrics_table.tex", "w") as f:
    f.write(df_quality.to_latex(multicolumn=True, multirow=True, float_format="%.3f"))

with open("french_app_confidence_correlation_table.tex", "w") as f:
    f.write(df_confidence.to_latex(multicolumn=True, multirow=True, float_format="%.3f"))
